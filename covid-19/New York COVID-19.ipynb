# %%
import covid_19_shared
covid_19_shared.USA_State_COVID19_Stats("New York").show()
# Out:
# Deaths Per Day
#             Daily Deaths Addition
# Date
# 2020-11-04                   13.0
# 2020-11-05                  101.0
# 2020-11-06                    7.0
# 2020-11-07                   16.0
# 2020-11-08                   14.0
# New Cases Per Day
#             Daily Cases Addition
# Date
# 2020-11-04                2126.0
# 2020-11-05                2997.0
# 2020-11-06                3209.0
# 2020-11-07                3587.0
# 2020-11-08                3428.0
