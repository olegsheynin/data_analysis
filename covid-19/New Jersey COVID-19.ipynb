# %%
import covid_19_shared
covid_19_shared.USA_State_COVID19_Stats("New Jersey").show()
# Out:
# Deaths Per Day
#             Daily Deaths Addition
# Date
# 2020-11-09                   11.0
# 2020-11-10                   21.0
# 2020-11-11                   15.0
# 2020-11-12                   19.0
# 2020-11-13                   27.0
# New Cases Per Day
#             Daily Cases Addition
# Date
# 2020-11-09                2058.0
# 2020-11-10                3777.0
# 2020-11-11                3065.0
# 2020-11-12                3491.0
# 2020-11-13                3397.0
