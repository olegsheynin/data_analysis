# %%
import covid_19_shared as cv19

print(cv19.list_of_USA_state_counties("New Jersey"))
cv19.USA_State_County_COVID19_Stats("New Jersey", "Bergen").show()
# Out:
# 1842      Atlantic
# 1843        Bergen
# 1844    Burlington
# 1845        Camden
# 1846      Cape May
# 1847    Cumberland
# 1848         Essex
# 1849    Gloucester
# 1850        Hudson
# 1851     Hunterdon
# 1852        Mercer
# 1853     Middlesex
# 1854      Monmouth
# 1855        Morris
# 1856         Ocean
# 1857     Out of NJ
# 1858       Passaic
# 1859         Salem
# 1860      Somerset
# 1861        Sussex
# 1862    Unassigned
# 1863         Union
# 1864        Warren
# Name: Admin2, dtype: object
# Deaths Per Day
#             Daily Deaths Addition
# Date
# 2021-01-18                    1.0
# 2021-01-19                    1.0
# 2021-01-20                   10.0
# 2021-01-21                    6.0
# 2021-01-22                    3.0
# New Cases Per Day
#             Daily Cases Addition
# Date
# 2021-01-18                 281.0
# 2021-01-19                 484.0
# 2021-01-20                 573.0
# 2021-01-21                 509.0
# 2021-01-22                 357.0
