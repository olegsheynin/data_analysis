# %%
import covid_19_shared
# covid_19_shared.USA_State_COVID19_Stats("New York").show()
# covid_19_shared.USA_State_COVID19_Stats("Illinois").show()
# covid_19_shared.USA_State_COVID19_Stats("Pennsylvania").show()
# covid_19_shared.USA_State_COVID19_Stats("Texas").show()
# covid_19_shared.USA_State_COVID19_Stats("California").show()
# covid_19_shared.USA_State_COVID19_Stats("South Dakota").show()
# covid_19_shared.USA_State_COVID19_Stats("Indiana").show()
# covid_19_shared.USA_State_COVID19_Stats("Ohio").show()
# covid_19_shared.USA_State_COVID19_Stats("Georgia").show()
# covid_19_shared.USA_State_COVID19_Stats("Virginia").show()
# covid_19_shared.USA_State_COVID19_Stats("Florida").show()
# covid_19_shared.USA_State_COVID19_Stats("Oklahoma").show()
# covid_19_shared.USA_State_COVID19_Stats("Maryland").show()
# covid_19_shared.USA_State_COVID19_Stats("Oklahoma").show()
covid_19_shared.USA_State_COVID19_Stats("Kentucky").show()
# Out:
# Deaths Per Day
#             Daily Deaths Addition
# Date
# 2021-06-07                   12.0
# 2021-06-08                    6.0
# 2021-06-09                   12.0
# 2021-06-10                   17.0
# 2021-06-11                    9.0
# 2021-06-12                    8.0
# 2021-06-13                    3.0
# 2021-06-14                    5.0
# New Cases Per Day
#             Daily Cases Addition
# Date
# 2021-06-07                 108.0
# 2021-06-08                 599.0
# 2021-06-09                 327.0
# 2021-06-10                 271.0
# 2021-06-11                 230.0
# 2021-06-12                 273.0
# 2021-06-13                  83.0
# 2021-06-14                 129.0
