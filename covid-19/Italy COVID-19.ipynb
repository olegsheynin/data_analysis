# %%
import covid_19_shared

# covid_19_shared.Country_COVID19_Stats("Italy").show()
# covid_19_shared.Country_COVID19_Stats("Ireland").show()
covid_19_shared.Country_COVID19_Stats("United Kingdom").show()
# covid_19_shared.Country_COVID19_Stats("Germany").show()
covid_19_shared.Country_COVID19_Stats("Russia").show()
# covid_19_shared.Country_COVID19_Stats("Israel").show()
#covid_19_shared.Country_COVID19_Stats("Brazil").show()
# covid_19_shared.Country_COVID19_Stats("Iran").show()
# covid_19_shared.Country_COVID19_Stats("Sweden").show()
# covid_19_shared.Country_COVID19_Stats("Chile").show()
# covid_19_shared.Country_COVID19_Stats("India").show()
# covid_19_shared.Country_COVID19_Stats("Peru").show()
# Out:
# Deaths Per Day
#             Daily Deaths Addition
# Date
# 2021-07-04                   15.0
# 2021-07-05                    9.0
# 2021-07-06                   37.0
# 2021-07-07                   33.0
# 2021-07-08                   36.0
# 2021-07-09                   30.0
# 2021-07-10                   34.0
# 2021-07-11                   26.0
# New Cases Per Day
#             Daily Cases Addition
# Date
# 2021-07-04               23896.0
# 2021-07-05               27106.0
# 2021-07-06               28629.0
# 2021-07-07               32061.0
# 2021-07-08               32096.0
# 2021-07-09               35885.0
# 2021-07-10               31835.0
# 2021-07-11               31382.0
# Deaths Per Day
#             Daily Deaths Addition
# Date
# 2021-07-04                  650.0
# 2021-07-05                  642.0
# 2021-07-06                  726.0
# 2021-07-07                  713.0
# 2021-07-08                  723.0
# 2021-07-09                  715.0
# ...
